# %% [markdown]
# SciPy docmentation
#
# [ch_square](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chisquare.html)
#
# [chi2_contingency](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi2_contingency.html)
#
# Youtube materials on related topic
#
# [Chi-Square Test [Simply explained]
# ](https://www.youtube.com/watch?v=rpKzq64GA9Y&t=298s
# )
