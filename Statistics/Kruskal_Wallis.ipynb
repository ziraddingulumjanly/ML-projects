# %% [markdown]
# Documentation:
#
# [Scipy documentation on related topic](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kruskal.html)
#
# Youtube materials on related topic
#
# [Kruskal-Wallis-Test (Simply explained)](https://www.youtube.com/watch?v=l86wEhUzkY4&t=8s
# )
