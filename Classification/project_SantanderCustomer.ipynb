# %% [markdown]
# Dataset: [Santander Customer Transaction Prediction Dataset
#  Kaggle](https://www.kaggle.com/datasets/lakshmi25npathi/santander-customer-transaction-prediction-dataset?resource=download)
